# %% [markdown]
# ## 疫情背景下一带一路相关政策词云图

# %% [markdown]
# ### 数据来源
# * 中华人民共和国中央人民政府 http://www.gov.cn/
# * 新华社 http://xinhuanet.com/
# * 人民网 http://www.people.com.cn/

# %% [markdown]
# ### 数据处理与可视化
# * 将所有相关政策文本爬取后保存在数据集中
# * Python读取政策文件并添加到文本库
# * 使用jieba包进行分词
# * 去除停用词，并去除已知关键词“一带”与“一路”
# * 统计词频
# * 使用pyecharts绘制词云图

# %%
import os
import re
import jieba
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType
path = 'data/政策数据/'
with open("data/stopwords.txt", "r", encoding="utf-8") as f:
    sw = [i.replace("\n", "") for i in f.readlines()]
words = []
sw.append("\n")
sw += ['一带', '一路', 'http', 'Post', 'htm', 'cn', 'gov']
for i in os.listdir(path):
    fn = path+i
    txt = open(fn, 'r', encoding='utf-8').read()
    words += jieba.lcut(txt)
_ = {}
for i in words:
    if i not in sw and len(i) > 1 and not bool(re.search(r'\d', i)):
        _[i] = _.get(i, 0) + 1
word = list(_.items())
c = (
    WordCloud()
    .add("", word, word_size_range=[20, 100], shape=SymbolType.TRIANGLE)
    .set_global_opts(title_opts=opts.TitleOpts(title="疫情背景下一带一路相关政策词云图"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="db859afa355845d99e7797e810bf73e6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_db859afa355845d99e7797e810bf73e6 = echarts.init(
#                     document.getElementById('db859afa355845d99e7797e810bf73e6'), 'white', {renderer: 'canvas'});
#                 var option_db859afa355845d99e7797e810bf73e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "triangle",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u91d1\u878d",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,23,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5408\u4f5c\u9879\u76ee",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,54,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56e0\u53d7",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,72,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u75ab\u60c5",
#                     "value": 277,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,110,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f71\u54cd",
#                     "value": 33,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,76,86)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9677\u5165",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,56,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u6b62",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(156,29,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9762\u5bf9",
#                     "value": 6,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,10,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd",
#                     "value": 310,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,92,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cbf\u7ebf",
#                     "value": 91,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,65,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56fd\u5bb6",
#                     "value": 250,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,14,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6846\u67b6",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,72,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u521b\u65b0",
#                     "value": 16,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,14,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5408\u4f5c",
#                     "value": 204,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,93,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u673a\u5236",
#                     "value": 21,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,148,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fce\u6765",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,117,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53d1\u5c55",
#                     "value": 155,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,94,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u673a\u9047",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,78,126)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c55\u671b\u672a\u6765",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,11,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u642d\u5efa",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,67,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u878d\u8d44",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,127,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e73\u53f0",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,87,55)"
